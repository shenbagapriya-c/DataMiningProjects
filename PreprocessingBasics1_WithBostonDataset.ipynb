# %%
import pandas as pd

# %%
#read data into pandas dataframe
# !dir
boston = pd.read_csv('boston.csv')
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 18FB-CF01
#
#  Directory of C:\Users\cshen\Documents\Q3_CIS508_DataMining_LabFiles\Week1
#
# 01/22/2022  10:11 PM    <DIR>          .
# 01/22/2022  10:11 PM    <DIR>          ..
# 01/22/2022  10:05 PM    <DIR>          .ipynb_checkpoints
# 01/18/2022  09:08 PM            31,855 boston.csv
# 01/22/2022  10:11 PM             1,843 boston_final.ipynb
# 01/22/2022  10:04 PM                72 Untitled.ipynb
# 01/18/2022  09:08 PM           201,578 Week 1 Lab File_Boston Housing Data.pdf
#                4 File(s)        235,348 bytes
#                3 Dir(s)  386,571,227,136 bytes free

# %%
#show first five rows
boston.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MDEV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
# show dimensions
boston.shape
# Out:
# (506, 13)

# %%
print(boston.isnull().sum())
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MDEV       0
# dtype: int64

# %%
boston.dtypes
# Out:
# CRIM        float64
# ZN          float64
# INDUS       float64
# CHAS       category
# NOX         float64
# RM          float64
# AGE         float64
# DIS         float64
# RAD           int64
# TAX           int64
# PTRATIO     float64
# LSTAT       float64
# MDEV        float64
# dtype: object

# %%
boston["CHAS"] = boston["CHAS"].astype("category")
boston.dtypes
# Out:
# CRIM        float64
# ZN          float64
# INDUS       float64
# CHAS       category
# NOX         float64
# RM          float64
# AGE         float64
# DIS         float64
# RAD           int64
# TAX           int64
# PTRATIO     float64
# LSTAT       float64
# MDEV        float64
# dtype: object

# %%
#the minimum value for CRIM - per capita crime rate by town
boston['CRIM'].min()
# Out:
# 3.593760711462451

# %%
#the maximum value for CRIM - per capita crime rate by town
boston['CRIM'].max()
# Out:
# 88.9762

# %%
#the average value for CRIM - per capita crime rate by townboston
boston['CRIM'].mean()
# Out:
# 3.593760711462451

# %%
# select first row
boston.iloc[0, ]
# Out:
# CRIM         0.00632
# ZN          18.00000
# INDUS        2.31000
# CHAS         0.00000
# NOX          0.53800
# RM           6.57500
# AGE         65.20000
# DIS          4.09000
# RAD          1.00000
# TAX        296.00000
# PTRATIO     15.30000
# LSTAT        4.98000
# MDEV        24.00000
# Name: 0, dtype: float64

# %%
# select three rows (row 2-4) and first column
boston.iloc[1:4,0]
# Out:
# 1    0.02731
# 2    0.02729
# 3    0.03237
# Name: CRIM, dtype: float64

# %%
boston.iloc[ 0:1 ,1 ]
# Out:
# 0    18.0
# Name: ZN, dtype: float64

# %%
#select three rows (row 1-4) and all columns
boston.iloc[:4, :]
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31  0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.0  0.458  6.998  45.8  6.0622    3  222     18.7
#
#    LSTAT  MDEV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4

# %%
#show top 5 rows where column "CHAS" is 1
boston[boston['CHAS']==1].head(5)
# Out:
#         CRIM   ZN  INDUS CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 142  3.32105  0.0  19.58  1.0  0.871  5.403  100.0  1.3216    5  403     14.7
# 152  1.12658  0.0  19.58  1.0  0.871  5.012   88.0  1.6102    5  403     14.7
# 154  1.41385  0.0  19.58  1.0  0.871  6.129   96.0  1.7494    5  403     14.7
# 155  3.53501  0.0  19.58  1.0  0.871  6.152   82.6  1.7455    5  403     14.7
# 160  1.27346  0.0  19.58  1.0  0.605  6.250   92.6  1.7984    5  403     14.7
#
#      LSTAT  MDEV
# 142  26.82  13.4
# 152  12.12  15.3
# 154  15.12  17.0
# 155  15.02  15.6
# 160   5.50  27.0

# %%
#select rows where column "CHAS" is 1 AND "RM" is larger than 2
boston[(boston['CHAS']==1) & (boston['RM'] > 6) & (boston['CRIM'] < 1)]
# Out:
#         CRIM    ZN  INDUS CHAS     NOX     RM   AGE     DIS  RAD  TAX  \
# 208  0.13587   0.0  10.59  1.0  0.4890  6.064  59.1  4.2392    4  277
# 219  0.11425   0.0  13.89  1.0  0.5500  6.373  92.4  3.3633    5  276
# 220  0.35809   0.0   6.20  1.0  0.5070  6.951  88.5  2.8617    8  307
# 221  0.40771   0.0   6.20  1.0  0.5070  6.164  91.3  3.0480    8  307
# 222  0.62356   0.0   6.20  1.0  0.5070  6.879  77.7  3.2721    8  307
# 234  0.44791   0.0   6.20  1.0  0.5070  6.726  66.5  3.6519    8  307
# 236  0.52058   0.0   6.20  1.0  0.5070  6.631  76.5  4.1480    8  307
# 273  0.22188  20.0   6.96  1.0  0.4640  7.691  51.8  4.3665    3  223
# 274  0.05644  40.0   6.41  1.0  0.4470  6.758  32.9  4.0776    4  254
# 276  0.10469  40.0   6.41  1.0  0.4470  7.267  49.0  4.7872    4  254
# 277  0.06127  40.0   6.41  1.0  0.4470  6.826  27.6  4.8628    4  254
# 282  0.06129  20.0   3.33  1.0  0.4429  7.645  49.7  5.2119    5  216
# 283  0.01501  90.0   1.21  1.0  0.4010  7.923  24.8  5.8850    1  198
#
#      PTRATIO  LSTAT  MDEV
# 208     18.6  14.66  24.4
# 219     16.4  10.50  23.0
# 220     17.4   9.71  26.7
# 221     17.4  21.46  21.7
# 222     17.4   9.93  27.5
# 234     17.4   8.05  29.0
# 236     17.4   9.54  25.1
# 273     18.6   6.58  35.2
# 274     17.6   3.53  32.4
# 276     17.6   6.05  33.2
# 277     17.6   4.16  33.1
# 282     14.9   3.01  46.0
# 283     13.6   3.16  50.0

# %%
# deleting a single row by row index
boston[boston.index != 0].head(2)
# Out:
#       CRIM   ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1  0.02731  0.0   7.07  0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729  0.0   7.07  0.0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#    LSTAT  MDEV
# 1   9.14  21.6
# 2   4.03  34.7

# %%
#delete column with parameter axis = 1
boston.drop('ZN', axis=1).head(2)
# Out:
#       CRIM  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  LSTAT  \
# 0  0.00632   2.31  0.0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 1  0.02731   7.07  0.0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
#
#    MDEV
# 0  24.0
# 1  21.6

# %%
#Handling Numerical Values

#import libraries
import numpy as np
from sklearn import preprocessing

# %%
#create Min-Max scaler to rescale values of numerical features to between two values
minmax_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
#select numerical variable
boston_numerical = boston.select_dtypes(include=np.number)

# %%
#scale features
scaled_boston = minmax_scaler.fit_transform(boston_numerical)
scaled_boston
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         2.87234043e-01, 8.96799117e-02, 4.22222222e-01],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         5.53191489e-01, 2.04470199e-01, 3.68888889e-01],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         5.53191489e-01, 6.34657837e-02, 6.60000000e-01],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 1.07891832e-01, 4.20000000e-01],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 1.31070640e-01, 3.77777778e-01],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 1.69701987e-01, 1.53333333e-01]])

# %%
#create a dataframe to save scaled features
scaled_boston_df = pd.DataFrame(scaled_boston, columns=boston_numerical.columns)
scaled_boston_df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040322    0.113636    0.391378    0.349167    0.521869    0.676364
# std      0.096626    0.233225    0.251479    0.238431    0.134627    0.289896
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.131687    0.445392    0.433831
# 50%      0.002812    0.000000    0.338343    0.314815    0.507281    0.768280
# 75%      0.040925    0.125000    0.646628    0.491770    0.586798    0.938980
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               DIS         RAD         TAX     PTRATIO       LSTAT        MDEV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.242381    0.371713    0.422208    0.622929    0.301409    0.389618
# std      0.191482    0.378576    0.321636    0.230313    0.197049    0.204380
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.088259    0.130435    0.175573    0.510638    0.144040    0.267222
# 50%      0.188949    0.173913    0.272901    0.686170    0.265728    0.360000
# 75%      0.369088    1.000000    0.914122    0.808511    0.420116    0.444444
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %%
#transform a feature to have a mean of 0 and a standard deviation of 1
scaler = preprocessing.StandardScaler()

# %%
#transform features
boston_standardized = scaler.fit_transform(boston_numerical)

# %%
#create a dataframe to save standardized features
standardized_boston_df = pd.DataFrame(boston_standardized, columns=boston_numerical.columns)
standardized_boston_df.describe()
# Out:
#                CRIM            ZN         INDUS           NOX            RM  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean   1.974705e-18  3.306534e-16  2.804081e-16 -8.071058e-16 -5.189086e-17
# std    1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00
# min   -4.177134e-01 -4.877224e-01 -1.557842e+00 -1.465882e+00 -3.880249e+00
# 25%   -4.088961e-01 -4.877224e-01 -8.676906e-01 -9.130288e-01 -5.686303e-01
# 50%   -3.885818e-01 -4.877224e-01 -2.110985e-01 -1.442174e-01 -1.084655e-01
# 75%    6.248255e-03  4.877224e-02  1.015999e+00  5.986790e-01  4.827678e-01
# max    9.941735e+00  3.804234e+00  2.422565e+00  2.732346e+00  3.555044e+00
#
#                 AGE           DIS           RAD           TAX       PTRATIO  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean  -2.650493e-16  8.293761e-17  1.514379e-15 -9.934960e-16  4.493551e-16
# std    1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00
# min   -2.335437e+00 -1.267069e+00 -9.828429e-01 -1.313990e+00 -2.707379e+00
# 25%   -8.374480e-01 -8.056878e-01 -6.379618e-01 -7.675760e-01 -4.880391e-01
# 50%    3.173816e-01 -2.793234e-01 -5.230014e-01 -4.646726e-01  2.748590e-01
# 75%    9.067981e-01  6.623709e-01  1.661245e+00  1.530926e+00  8.065758e-01
# max    1.117494e+00  3.960518e+00  1.661245e+00  1.798194e+00  1.638828e+00
#
#               LSTAT          MDEV
# count  5.060000e+02  5.060000e+02
# mean  -1.595123e-16 -4.247810e-16
# std    1.000990e+00  1.000990e+00
# min   -1.531127e+00 -1.908226e+00
# 25%   -7.994200e-01 -5.994557e-01
# 50%   -1.812536e-01 -1.450593e-01
# 75%    6.030188e-01  2.685231e-01
# max    3.548771e+00  2.989460e+00

# %%
#Handle Missing Values

#NAN: not a number
boston.head(10)
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31  0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07  0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07  0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18  0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18  0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18  NaN  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87  0.0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87  0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87  0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87  NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MDEV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# 5   5.21  28.7
# 6  12.43  22.9
# 7  19.15  27.1
# 8  29.93  16.5
# 9  17.10  18.9

# %%
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       3
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MDEV       0
# dtype: int64

# %%
boston.isnull().sum().sum()
# Out:
# 0

# %%
# fill Nan with 0 (or fill with the average)
boston['CHAS'] = boston['CHAS'].fillna(0)

# %%
# .isnull() to check missing values
print(boston[['CHAS']].isnull().sum())
# Out:
# CHAS    0
# dtype: int64

# %%
# drop rows with missing values
boston.dropna(inplace=True)
print(boston.shape)
# Out:
# (506, 13)

# %%
#import libraries for data visualization
import seaborn as sns

# %%
#histgram to show the distribution of MDEV
sns.histplot(boston['MDEV'],color='red')
# Out:
# <AxesSubplot:xlabel='MDEV', ylabel='Count'>

# %%
#boxplot of the of MDEV
sns.boxplot(y='MDEV',data=boston)
# Out:
# <AxesSubplot:ylabel='MDEV'>

# %%
#boxplot of the MDEV variable(MDEV) across the Charles River dummy variable (CHAS)
sns.boxplot(x='CHAS',y='MDEV',data=boston)
# Out:
# C:\Users\cshen\anaconda3\lib\site-packages\pandas\io\formats\format.py:1405: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# <AxesSubplot:xlabel='CHAS', ylabel='MDEV'>

# %%
sns.scatterplot(x='LSTAT', y='MDEV', data = boston, legend=False)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MDEV'>
